# %%
#1 importing nltk
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\ishaa\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# ...

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#2 retreiving data
from nltk.corpus import brown
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
from nltk.corpus import inaugral
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-6b6f758f551a> in <module>()
# ----> 1 from nltk.corpus import inaugral
#
# ImportError: cannot import name 'inaugral'

# %%
#3 daata access
from nltk.corpus import inaugural
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
# ...

# %%
inaugural.words(fileids='2017-Trump.txt')[:50]
# Out:
# ['Chief',
#  'Justice',
#  'Roberts',
#  ',',
#  'President',
#  'Carter',
#  ',',
#  'President',
#  'Clinton',
#  ',',
#  'President',
#  'Bush',
#  ',',
#  'President',
#  'Obama',
#  ',',
#  'fellow',
#  'Americans',
#  ',',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world',
#  ':',
#  'Thank',
#  'you',
#  '.',
#  'We',
#  ',',
#  'the',
#  'citizens',
#  'of',
#  'America',
#  ',',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'restore',
#  'its']

# %%
#4 frequency distribution
text1='SMS Derfflinger was a battlecruiser of the German Kaiserliche Marine built in the early 1910s, the lead vessel of the Derfflinger class. The ships were larger than the previous German battlecruisers, and featured significant improvements. Derfflinger served in I Scouting Group during the war and took part in attacks on Scarborough, Hartlepool and Whitby in 1914 and Yarmouth and Lowestoft in 1916, as well as the Battle of Dogger Bank in 1915 and the Battle of Jutland in 1916. At Jutland, Derfflinger helped to sink the British battlecruisers Queen Mary and Invincible, but was seriously damaged herself'
fd=nltk.FreqDist(text1.split())
fd
# Out:
# FreqDist({'the': 9, 'in': 7, 'and': 7, 'Derfflinger': 4, 'of': 4, 'was': 2, 'German': 2, 'as': 2, 'Battle': 2, 'SMS': 1, ...})

# %%
#5 conditional frequency
from nltk.probability import ConditionalFreqDist
cfd=ConditionalFreqDist((len(word),word)for word in text1.split())
cfd[5]
# Out:
# FreqDist({'built': 1, 'early': 1, 'ships': 1, 'Group': 1, '1916,': 1, '1916.': 1, 'Queen': 1})

# %%
text1=inaugural.words(fileids='2017-Trump.txt')[:50]
from nltk.probability import ConditionalFreqDist

# %%
cfd=ConditionalFreqDist((len(word),word)for word in text1.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e9e24fb14195> in <module>()
# ----> 1 cfd=ConditionalFreqDist((len(word),word)for word in text1.split())
#
# AttributeError: 'list' object has no attribute 'split'

# %%
inaugural.words(fileids='2017-Trump.txt')[:50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8a8b3a3f6368> in <module>()
# ----> 1 inaugural.words(fileids='2017-Trump.txt')[:50]
#
# NameError: name 'inaugural' is not defined

# %%
from nltk corpus import inaugural
# Out:
#   File "<ipython-input-2-c50354164b89>", line 1
#     from nltk corpus import inaugural
#                    ^
# SyntaxError: invalid syntax

# %%
from nltk.corpus import inaugural

# %%
inaugural.words(fileids='2017-Trump.txt')[:50]
# Out:
# ['Chief',
#  'Justice',
#  'Roberts',
#  ',',
#  'President',
#  'Carter',
#  ',',
#  'President',
#  'Clinton',
#  ',',
#  'President',
#  'Bush',
#  ',',
#  'President',
#  'Obama',
#  ',',
#  'fellow',
#  'Americans',
#  ',',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world',
#  ':',
#  'Thank',
#  'you',
#  '.',
#  'We',
#  ',',
#  'the',
#  'citizens',
#  'of',
#  'America',
#  ',',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'restore',
#  'its']

# %%
inaugural.words(fileids='2017-Trump.txt')[:50]
# Out:
# ['Chief',
#  'Justice',
#  'Roberts',
#  ',',
#  'President',
#  'Carter',
#  ',',
#  'President',
#  'Clinton',
#  ',',
#  'President',
#  'Bush',
#  ',',
#  'President',
#  'Obama',
#  ',',
#  'fellow',
#  'Americans',
#  ',',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world',
#  ':',
#  'Thank',
#  'you',
#  '.',
#  'We',
#  ',',
#  'the',
#  'citizens',
#  'of',
#  'America',
#  ',',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'restore',
#  'its']

# %%
speech=inaugural.words(fileids='2017-Trump.txt')[:50]

# %%
speech
# Out:
# ['Chief',
#  'Justice',
#  'Roberts',
#  ',',
#  'President',
#  'Carter',
#  ',',
#  'President',
#  'Clinton',
#  ',',
#  'President',
#  'Bush',
#  ',',
#  'President',
#  'Obama',
#  ',',
#  'fellow',
#  'Americans',
#  ',',
#  'and',
#  'people',
#  'of',
#  'the',
#  'world',
#  ':',
#  'Thank',
#  'you',
#  '.',
#  'We',
#  ',',
#  'the',
#  'citizens',
#  'of',
#  'America',
#  ',',
#  'are',
#  'now',
#  'joined',
#  'in',
#  'a',
#  'great',
#  'national',
#  'effort',
#  'to',
#  'rebuild',
#  'our',
#  'country',
#  'and',
#  'restore',
#  'its']

# %%
str1=""

# %%
for ele in speech:
    str1+=ele

# %%
str1
# Out:
# 'ChiefJusticeRoberts,PresidentCarter,PresidentClinton,PresidentBush,PresidentObama,fellowAmericans,andpeopleoftheworld:Thankyou.We,thecitizensofAmerica,arenowjoinedinagreatnationalefforttorebuildourcountryandrestoreits'

# %%
from nltk.probability import ConditionalFreqDist
cfd=ConditionalFreqDist((len(word),word)for word in str1.split())
cfd[5]
# Out:
# FreqDist({})

# %%
from nltk.probability import ConditionalFreqDist
cfd=ConditionalFreqDist((len(word),word)for word in text1.split())
cfd[20]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bf54f9e7e1fb> in <module>()
#       1 from nltk.probability import ConditionalFreqDist
# ----> 2 cfd=ConditionalFreqDist((len(word),word)for word in text1.split())
#       3 cfd[20]
#
# NameError: name 'text1' is not defined

# %%
from nltk.probability import ConditionalFreqDist
cfd=ConditionalFreqDist((len(word),word)for word in str1.split())
cfd[20]
# Out:
# FreqDist({})

# %%
str2=""

# %%
for ele in speech:
    str1=str1+" "+ele

# %%
for ele in speech:
    str2=str2+" "+ele

# %%
str2
# Out:
# ' Chief Justice Roberts , President Carter , President Clinton , President Bush , President Obama , fellow Americans , and people of the world : Thank you . We , the citizens of America , are now joined in a great national effort to rebuild our country and restore its'

# %%
#6 conditional frequency for president speech
from nltk.probability import ConditionalFreqDist
cfd=ConditionalFreqDist((len(word),word)for word in str2.split())
cfd[5]
# Out:
# FreqDist({'Chief': 1, 'Obama': 1, 'world': 1, 'Thank': 1, 'great': 1})

# %%
#7 lexicons
collection of words/Phrases + Information (POS; tense Definitions..)

#1. STOPWORDS
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
#2 CMU LIST

import nltk
enteries=nltk.corpus.cmudict.enteries()
len(enteries)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-ac1574b642b1> in <module>()
#       2
#       3 import nltk
# ----> 4 enteries=nltk.corpus.cmudict.enteries()
#       5 len(enteries)
#
# D:\python\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     117         # This looks circular, but its not, since __load() changes our
#     118         # __class__ to something new:
# --> 119         return getattr(self, attr)
#     120
#     121     def __repr__(self):
#
# AttributeError: 'CMUDictCorpusReader' object has no attribute 'enteries'

# %%
#2 CMU LIST

import nltk
entries=nltk.corpus.cmudict.entries()
len(entries)
# Out:
# 133737

# %%
#3 WORDNET
from nltk.corpus import wordnet as wn
wn.synsets('motocar')
# Out:
# []

# %%
#3 WORDNET
from nltk.corpus import wordnet as wn
wn.synsets('motorcar')
# Out:
# [Synset('car.n.01')]

# %%
wn.synset('car.n.01').lemma_names()
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar']

# %%
#8 STEMMING 
import nltk
from nltk.stem import PorterStemmer
stemmerporter=PorterStemmer()
stemmerporter.stem('happiness')
# Out:
# 'happi'

# %%
import nltk
from nltk.stem import LancasterStemmer
stemmerlan=LancasterStemmer()
stemmerlan.stem('happiness')
# Out:
# 'happy'

# %%
import nltk
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
frenchstemmer=SnowballStemmer('french')
frenchstemmer.stem('manges')
# Out:
# 'mang'

# %%
#9 STEMMING PARAGRAPH
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
example="Am quick brown fox jumps over a lazy dog"
example=[stemmer.stem(token)for token in example.split(" ")]
print(" ".join(example))
# Out:
# Am quick brown fox jump over a lazi dog

# %%
# LEMMATIZER
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
print(lemmatizer.lemmatize("cacti"))
# Out:
# cactus

# %%
print(lemmatizer.lemmatize("better",pos='a'))
# Out:
# good

# %%
print(lemmatizer.lemmatize("am",pos='v'))
# Out:
# be

# %%
#11 CHINESE SEGMENTATION USING JIEBA
import jieba
seg=jieba.cut("中文维基百科",cut_all=True)
print(" ".join(seg))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ishaa\AppData\Local\Temp\jieba.cache
# Loading model cost 1.652 seconds.
# Prefix dict has been built successfully.
# 中文 维基 维基百 维基百科 百科

# %%
#12 BASIC TEXT PROCESSING PIPELINE
import nltk
text1='''Originally, I was disappointed by the high prices of these watches. I didn't want to drop $700 on a watch when I wasn't sure I would even use a watch. However, I ended up being very happy with the Sport, and I'm convinced it's what I would have chosen even if my funds allowed me other choices-- at least, that's what I tell myself. :) My mom, who also likes to have the latest gadget, got the Watch version, meaning I have a pretty good basis of comparison, so I'll start with that. '''
for text in text1:
    sentences=nltk.sent_tokenize(text1)
    for sentence in sentences:
        words=nltk.word_tokenize(sentence)
        tagged=nltk.pos_tag(words)
        print(tagged)
# Out:
# [('Originally', 'RB'), (',', ','), ('I', 'PRP'), ('was', 'VBD'), ('disappointed', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('high', 'JJ'), ('prices', 'NNS'), ('of', 'IN'), ('these', 'DT'), ('watches', 'NNS'), ('.', '.')]
# [('I', 'PRP'), ('did', 'VBD'), ("n't", 'RB'), ('want', 'VB'), ('to', 'TO'), ('drop', 'VB'), ('$', '$'), ('700', 'CD'), ('on', 'IN'), ('a', 'DT'), ('watch', 'NN'), ('when', 'WRB'), ('I', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('sure', 'JJ'), ('I', 'PRP'), ('would', 'MD'), ('even', 'RB'), ('use', 'VB'), ('a', 'DT'), ('watch', 'NN'), ('.', '.')]
# ...

# %%
#13 TWEET TOKENIZER
from nltk.tokenize import TweetTokenizer
text='The Party was soo fun :D #superfun'
twtkn=TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'Party', 'was', 'soo', 'fun', ':D', '#superfun']

# %%
#14 SCRAPING DATA FROM WEB
from urllib import request
url="http://www.gutenberg.org/files/2554/2554-0.txt"
response=request.urlopen(url)
raw=response.read().decode('utf8')
type(raw)
len(raw)
raw[:75]
from nltk.tokenize import word_tokenize
tokens=word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
#15 HANDLING TWEETS DATA
import nltk
f=open('C:\\Users\\ishaa\\Downloads\\tweets1.txt','r')
text=f.read()
text1=text.split()
text2=nltk.Text(text1)
text2.concordance("good")
# Out:
# Displaying 17 of 17 matches:
# In The Signal premiere. Lotsa buyers. Good luck gang listening to the pocast net
#  so going to enjoy this shower. Feels good to have worked on a trail three times
# tose not my friend. it was not a very good day so I have a lot to do tomorrow..I
#  Oh why cheesecake why? You looked so good evil cake. Now metamucil. Reading: "M
# autiful day so Im thinking to spend a good part of it outdoors.first stop at Sta
# ng and ignoring my reaction to a very good friend getting fired. it's like a bir
# nd HDH - url wrist sprain= damn pain. good thing it's not on my left hand. Being
# s I bet I can throw farther than her. Good luck with that dude. Sure it will all
# n Choppers. first day of eid .. feels good Looking to buy a game called Shut the
# ng. back from the ASLA 6 Congress. :) Good job ASLA CORE! I'm gonna need to step
# atching the CNBC video of David Lear. Good job Sean! and now... off to Belize! f
# ...

# %%
#16 SIMPLE TEXT CLASSIFICATION
def gender_features(word):
    return{'last_letter':word[-1]}

# %%
from nltk.corpus import names

# %%
names.words()
# Out:
# ['Abagael',
#  'Abagail',
#  'Abbe',
#  'Abbey',
#  'Abbi',
#  'Abbie',
#  'Abby',
#  'Abigael',
#  'Abigail',
#  'Abigale',
#  'Abra',
#  'Acacia',
#  'Ada',
#  'Adah',
#  'Adaline',
#  'Adara',
#  'Addie',
#  'Addis',
#  'Adel',
#  'Adela',
#  'Adelaide',
#  'Adele',
#  'Adelice',
#  'Adelina',
#  'Adelind',
#  'Adeline',
#  'Adella',
#  'Adelle',
#  'Adena',
#  'Adey',
#  'Adi',
#  'Adiana',
#  'Adina',
#  'Adora',
#  'Adore',
#  'Adoree',
#  'Adorne',
#  'Adrea',
#  'Adria',
#  'Adriaens',
#  'Adrian',
#  'Adriana',
#  'Adriane',
#  'Adrianna',
#  'Adrianne',
#  'Adrien',
#  'Adriena',
#  'Adrienne',
#  'Aeriel',
#  'Aeriela',
#  'Aeriell',
#  'Ag',
#  'Agace',
#  'Agata',
#  'Agatha',
#  'Agathe',
#  'Aggi',
#  'Aggie',
#  'Aggy',
#  'Agna',
#  'Agnella',
#  'Agnes',
#  'Agnese',
#  'Agnesse',
#  'Agneta',
#  'Agnola',
#  'Agretha',
#  'Aida',
#  'Aidan',
#  'Aigneis',
#  'Aila',
#  'Aile',
#  'Ailee',
#  'Aileen',
#  'Ailene',
#  'Ailey',
#  'Aili',
#  'Ailina',
#  'Ailyn',
# ...

# %%
labeled_names=([(name,'male')for name in names.words('male.txt')]+[(name,'female')for name in names.words('female.txt')])

# %%
import random
random.shuffle(labeled_names)
featuresets=[(gender_features(n),gender)for (n,gender) in labeled_names]

# %%
train_set,test_set=featuresets[:5000],featuresets[5000:]
import nltk
classifier=nltk.NaiveBayesClassifier.train(train_set)

# %%
classifier.classify(gender_features('David'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Ishaan'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Muskan'))
# Out:
# 'male'

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.7547554347826086

# %%
#17 COUNT VECTORIZER
from sklearn.feature_extraction.text import CountVectorizer
vect=CountVectorizer(binary=True)
corpus=["Tessaract is good optical character recognition engine ","optical character recognition is significant"]
vect.fit(corpus)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
vocab=vect.vocabulary_

# %%
for key in sorted(vocab.keys()):
    print("{}:{}".format(key,vocab[key]))
# Out:
# character:0
# engine:1
# good:2
# is:3
# optical:4
# recognition:5
# significant:6
# tessaract:7

# %%
print(vect.transform(["This is a good optical illusion"]).toarray())
# Out:
# [[0 0 1 1 1 0 0 0]]

# %%
#18 FINDING SIMILARITY BETWEEN DOCUMENTS
from sklearn.metrics.pairwise import cosine_similarity
similarity= cosine_similarity(vect.transform(["Google Cloud Vision is a character recognition engine"]).toarray(),vect.transform(["OCR is an optical character recognition engine"]).toarray())
print(similarity)
# Out:
# [[0.89442719]]
